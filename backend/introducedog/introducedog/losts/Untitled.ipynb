# %%
data = {}
data['img_url'] = "https://new-aws-album.s3.ap-northeast-2.amazonaws.com/%EB%A7%90%ED%8B%B0%EC%A6%88.jpg"

# %%
data
# Out:
# {'img_url': 'https://new-aws-album.s3.ap-northeast-2.amazonaws.com/%EB%A7%90%ED%8B%B0%EC%A6%88.jpg'}

# %%
import json
import logging
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
from keras.models import load_model
from PIL import Image
from django.shortcuts import get_object_or_404, render
from django.shortcuts import render
from django.views import View
from django.http import HttpResponse, JsonResponse

# %%
img = io.imread(data['img_url'])
plt.imshow(img)

# %%
image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = img

# %%
 model = load_model(
            'C:\\Users\\multicampus\\Desktop\\jin\\s03p23a307\\backend\\introducedog\\introducedog\\losts\\dog_recog_model.h5')

# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model

from io import BytesIO

# %%
res = request.urlopen(data['img_url']).read()
img = Image.open(BytesIO(res))

# %%
img = img.convert("RGB")

# %%
img = img.resize((image_w, image_h))

# %%
data = np.asarray(img)

# %%
filenames.append(file)

# %%
X.append(data)

# %%
X = np.array(X)

# %%
prediction = model.predict(X)

# %%
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

# %%
cnt = 0

# %%
for i in prediction:
    pre_ans = i.argmax()  # 예측 레이블
    print(i)
    print(pre_ans)
    pre_ans_str = ''
    if pre_ans == 0: pre_ans_str = "포메"
    elif pre_ans == 1: pre_ans_str = "말티즈"
    elif pre_ans == 2: pre_ans_str = "치와와"
    elif pre_ans == 3: pre_ans_str = "토이푸들"
    else: pre_ans_str = "골든리트리버"
    print(pre_ans_str)
    cnt += 1
# Out:
# [0.000 0.000 1.000 0.000 0.000]
# 2
# 치와와

# %%
file
# Out:
# []

# %%
# Out:
# 1.0

# %%
# Out:
# 0.0

# %%
# Out:
# 2

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-1aa978b46d72> in <module>
# ----> 1 res = request.urlopen(url).read()
#       2 img = Image.open(BytesIO(res))
#
# NameError: name 'url' is not defined
